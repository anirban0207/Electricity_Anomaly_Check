# %%
import pandas as pd
import matplotlib.pyplot as plt

print("everything working")
# Out:
# everything working

# %%
import pandas as pd

df = pd.read_csv("../data/sample_daily_electricity_usage.csv")

print("Loaded sample successfully")
print(df.head())
# Out:
# Loaded sample successfully
#    Meter ID        date  total daily KW
# 0      1000  2009-07-14          11.203
# 1      1000  2009-07-15           8.403
# 2      1000  2009-07-16           7.225
# 3      1000  2009-07-17          11.338
# 4      1000  2009-07-18          11.306
